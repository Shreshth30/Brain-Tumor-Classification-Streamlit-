# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from  keras.preprocessing.image import *

# %%
no_dir = '/content/drive/MyDrive/brain tumor/brain_tumor_dataset/no_tumor'
yes_dir = '/content/drive/MyDrive/brain tumor/brain_tumor_dataset/tumor'

# %%
img_to_array(load_img(os.path.join(no_dir , os.listdir(no_dir)[5]))).shape
# Out:
# (338, 276, 3)

# %%
dst = pd.DataFrame()
dst['answer'] = ['1'] * len(os.listdir(yes_dir)) + ['0'] * len(os.listdir(no_dir))

sns.countplot(x='answer', data=dst)

# %%
plt.figure(figsize=(15, 15))
plt.subplot(4, 4, 1)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[0])))
plt.title('yes')
plt.subplot(4, 4, 2)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[1])))
plt.title('yes')

plt.subplot(4, 4, 3)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[2])))
plt.title('yes')

plt.subplot(4, 4, 4)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[3])))
plt.title('yes')

plt.subplot(4, 4, 5)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[4])))
plt.title('yes')

plt.subplot(4, 4, 6)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[5])))
plt.title('yes')

plt.subplot(4, 4, 7)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[6])))
plt.title('yes')

plt.subplot(4, 4, 8)
plt.imshow(load_img(os.path.join(yes_dir , os.listdir(yes_dir)[7])))
plt.title('yes')

plt.subplot(4, 4, 9)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[0])))
plt.title('no')
plt.subplot(4, 4, 10)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[1])))
plt.title('no')

plt.subplot(4, 4, 11)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[2])))
plt.title('no')

plt.subplot(4, 4, 12)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[3])))
plt.title('no')

plt.subplot(4, 4, 13)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[4])))
plt.title('no')

plt.subplot(4, 4, 14)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[5])))
plt.title('no')

plt.subplot(4, 4, 15)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[6])))
plt.title('no')

plt.subplot(4, 4, 16)
plt.imshow(load_img(os.path.join(no_dir , os.listdir(no_dir)[7])))
plt.title('no')
plt.show()

# %%
base_dir = '/content/drive/MyDrive/brain tumor/brain_tumor_dataset'

datagen = ImageDataGenerator(rescale=1/255,
                             rotation_range=20,
                             horizontal_flip=True,
                             height_shift_range=0.1,
                             width_shift_range=0.1,
                             shear_range=0.1,
                             brightness_range=[0.3, 1.5],
                             validation_split=0.2
                            )

train_gen= datagen.flow_from_directory(base_dir,
                                       target_size=(224,224),
                                       class_mode='binary',
                                       subset='training'
                                      )
val_gen = datagen.flow_from_directory( base_dir,
                                       target_size=(224,224),
                                       class_mode='binary',
                                       subset='validation'
                                      )
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %%
from keras.models import *
from keras.layers import *

from keras.applications.vgg16 import VGG16

VGG = VGG16(
    weights = 'imagenet',
    include_top = False,
    input_shape = (224,224, 3)
)

VGG.trainable = False
model = Sequential()
model.add(VGG)
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'])


history = model.fit(
    train_gen,
    epochs = 20,
    batch_size = 32,
    validation_data = val_gen
)

plt.figure(figsize=(15, 15))

plt.subplot(2,2, 1)
sns.lineplot(data = history.history, x = range(20), y = 'val_accuracy')
sns.lineplot(data = history.history, x = range(20), y = 'accuracy')
plt.legend()

plt.subplot(2,2, 2)
sns.lineplot(data = history.history, x = range(20), y = 'val_loss')
sns.lineplot(data = history.history, x = range(20), y = 'loss')
plt.legend()

from keras import optimizers

VGG.trainable = True
set_trainable = False

for layer in VGG.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

from keras import optimizers

model.compile(
    optimizer = optimizers.RMSprop(lr = 1e-5),
    loss = 'binary_crossentropy',
    metrics= ['accuracy']
)

history = model.fit(
    train_gen,
    batch_size = 20,
    epochs = 30,
    validation_data = val_gen
)

plt.subplot(2,2, 3)
sns.lineplot(data = history.history, x = range(30), y = 'val_accuracy')
sns.lineplot(data = history.history, x = range(30), y = 'accuracy')
plt.legend()

plt.subplot(2,2, 4)
sns.lineplot(data = history.history, x = range(30), y = 'val_loss')
sns.lineplot(data = history.history, x = range(30), y = 'loss')
plt.legend()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Epoch 1/20
# 7/7 [==============================] - 119s 9s/step - loss: 0.9503 - accuracy: 0.5106 - val_loss: 0.6520 - val_accuracy: 0.7600
# Epoch 2/20
# 7/7 [==============================] - 5s 736ms/step - loss: 0.4863 - accuracy: 0.7732 - val_loss: 0.5409 - val_accuracy: 0.8200
# Epoch 3/20
# 7/7 [==============================] - 5s 746ms/step - loss: 0.4323 - accuracy: 0.8408 - val_loss: 0.6027 - val_accuracy: 0.7600
# Epoch 4/20
# 7/7 [==============================] - 5s 734ms/step - loss: 0.2932 - accuracy: 0.8552 - val_loss: 0.7361 - val_accuracy: 0.7600
# Epoch 5/20
# 7/7 [==============================] - 5s 809ms/step - loss: 0.3081 - accuracy: 0.8848 - val_loss: 0.5831 - val_accuracy: 0.7200
# Epoch 6/20
# 7/7 [==============================] - 5s 739ms/step - loss: 0.3043 - accuracy: 0.8772 - val_loss: 0.4787 - val_accuracy: 0.8200
# Epoch 7/20
# 7/7 [==============================] - 5s 736ms/step - loss: 0.3752 - accuracy: 0.8308 - val_loss: 0.8384 - val_accuracy: 0.6400
# Epoch 8/20
# 7/7 [==============================] - 5s 724ms/step - loss: 0.2679 - accuracy: 0.8924 - val_loss: 1.3000 - val_accuracy: 0.5000
# Epoch 9/20
# 7/7 [==============================] - 5s 726ms/step - loss: 0.3098 - accuracy: 0.8817 - val_loss: 0.4376 - val_accuracy: 0.8000
# Epoch 10/20
# 7/7 [==============================] - 5s 723ms/step - loss: 0.2987 - accuracy: 0.8498 - val_loss: 0.3911 - val_accuracy: 0.8200
# Epoch 11/20
# 7/7 [==============================] - 5s 732ms/step - loss: 0.2460 - accuracy: 0.9273 - val_loss: 0.5306 - val_accuracy: 0.7200
# Epoch 12/20
# 7/7 [==============================] - 5s 735ms/step - loss: 0.2357 - accuracy: 0.9165 - val_loss: 0.4859 - val_accuracy: 0.8200
# Epoch 13/20
# 7/7 [==============================] - 5s 742ms/step - loss: 0.2853 - accuracy: 0.8835 - val_loss: 0.8492 - val_accuracy: 0.6000
# Epoch 14/20
# 7/7 [==============================] - 5s 729ms/step - loss: 0.2989 - accuracy: 0.9037 - val_loss: 0.5795 - val_accuracy: 0.7200
# Epoch 15/20
# 7/7 [==============================] - 5s 730ms/step - loss: 0.3361 - accuracy: 0.8574 - val_loss: 0.4726 - val_accuracy: 0.7400
# Epoch 16/20
# 7/7 [==============================] - 5s 806ms/step - loss: 0.2717 - accuracy: 0.9101 - val_loss: 0.4045 - val_accuracy: 0.8400
# Epoch 17/20
# 7/7 [==============================] - 5s 727ms/step - loss: 0.2503 - accuracy: 0.9013 - val_loss: 0.3427 - val_accuracy: 0.8200
# Epoch 18/20
# 7/7 [==============================] - 5s 810ms/step - loss: 0.2686 - accuracy: 0.9390 - val_loss: 0.4018 - val_accuracy: 0.8000
# Epoch 19/20
# 7/7 [==============================] - 5s 744ms/step - loss: 0.2484 - accuracy: 0.9203 - val_loss: 0.3328 - val_accuracy: 0.8800
# Epoch 20/20
# 7/7 [==============================] - 5s 736ms/step - loss: 0.2903 - accuracy: 0.8944 - val_loss: 0.3972 - val_accuracy: 0.8200
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/30
# 7/7 [==============================] - 10s 909ms/step - loss: 0.2732 - accuracy: 0.9316 - val_loss: 0.4598 - val_accuracy: 0.8200
# Epoch 2/30
# 7/7 [==============================] - 5s 731ms/step - loss: 0.2372 - accuracy: 0.9360 - val_loss: 0.4557 - val_accuracy: 0.8200
# Epoch 3/30
# 7/7 [==============================] - 5s 753ms/step - loss: 0.2149 - accuracy: 0.9326 - val_loss: 0.4526 - val_accuracy: 0.8000
# Epoch 4/30
# 7/7 [==============================] - 5s 752ms/step - loss: 0.2254 - accuracy: 0.9518 - val_loss: 0.4123 - val_accuracy: 0.8200
# Epoch 5/30
# 7/7 [==============================] - 5s 757ms/step - loss: 0.2186 - accuracy: 0.9385 - val_loss: 0.3916 - val_accuracy: 0.8600
# Epoch 6/30
# 7/7 [==============================] - 5s 749ms/step - loss: 0.2226 - accuracy: 0.9374 - val_loss: 0.4344 - val_accuracy: 0.8400
# Epoch 7/30
# 7/7 [==============================] - 5s 748ms/step - loss: 0.1935 - accuracy: 0.9712 - val_loss: 0.3865 - val_accuracy: 0.8200
# Epoch 8/30
# 7/7 [==============================] - 5s 741ms/step - loss: 0.2219 - accuracy: 0.9290 - val_loss: 0.3216 - val_accuracy: 0.8200
# Epoch 9/30
# 7/7 [==============================] - 5s 751ms/step - loss: 0.2227 - accuracy: 0.9194 - val_loss: 0.2737 - val_accuracy: 0.9000
# Epoch 10/30
# 7/7 [==============================] - 5s 827ms/step - loss: 0.1693 - accuracy: 0.9669 - val_loss: 0.2964 - val_accuracy: 0.8400
# Epoch 11/30
# 7/7 [==============================] - 5s 759ms/step - loss: 0.2131 - accuracy: 0.9416 - val_loss: 0.3293 - val_accuracy: 0.8600
# Epoch 12/30
# 7/7 [==============================] - 5s 755ms/step - loss: 0.2017 - accuracy: 0.9427 - val_loss: 0.3927 - val_accuracy: 0.8200
# Epoch 13/30
# 7/7 [==============================] - 5s 747ms/step - loss: 0.1618 - accuracy: 0.9635 - val_loss: 0.3108 - val_accuracy: 0.8600
# Epoch 14/30
# 7/7 [==============================] - 5s 744ms/step - loss: 0.1468 - accuracy: 0.9955 - val_loss: 0.3681 - val_accuracy: 0.8400
# Epoch 15/30
# 7/7 [==============================] - 5s 759ms/step - loss: 0.1694 - accuracy: 0.9582 - val_loss: 0.2889 - val_accuracy: 0.9000
# Epoch 16/30
# 7/7 [==============================] - 5s 752ms/step - loss: 0.1478 - accuracy: 0.9902 - val_loss: 0.3176 - val_accuracy: 0.8800
# Epoch 17/30
# 7/7 [==============================] - 5s 753ms/step - loss: 0.1549 - accuracy: 0.9879 - val_loss: 0.2959 - val_accuracy: 0.8400
# Epoch 18/30
# 7/7 [==============================] - 5s 753ms/step - loss: 0.1333 - accuracy: 0.9809 - val_loss: 0.2870 - val_accuracy: 0.8400
# Epoch 19/30
# 7/7 [==============================] - 5s 746ms/step - loss: 0.1468 - accuracy: 0.9616 - val_loss: 0.3287 - val_accuracy: 0.8800
# Epoch 20/30
# 7/7 [==============================] - 5s 844ms/step - loss: 0.1632 - accuracy: 0.9817 - val_loss: 0.3365 - val_accuracy: 0.8600
# Epoch 21/30
# 7/7 [==============================] - 5s 777ms/step - loss: 0.1271 - accuracy: 0.9904 - val_loss: 0.2728 - val_accuracy: 0.8800
# Epoch 22/30
# 7/7 [==============================] - 5s 768ms/step - loss: 0.1415 - accuracy: 0.9900 - val_loss: 0.2876 - val_accuracy: 0.9000
# Epoch 23/30
# 7/7 [==============================] - 5s 745ms/step - loss: 0.1416 - accuracy: 0.9726 - val_loss: 0.2703 - val_accuracy: 0.9000
# Epoch 24/30
# 7/7 [==============================] - 5s 760ms/step - loss: 0.1363 - accuracy: 0.9657 - val_loss: 0.2660 - val_accuracy: 0.8400
# Epoch 25/30
# 7/7 [==============================] - 5s 832ms/step - loss: 0.1626 - accuracy: 0.9683 - val_loss: 0.2924 - val_accuracy: 0.9000
# Epoch 26/30
# 7/7 [==============================] - 5s 746ms/step - loss: 0.1222 - accuracy: 0.9854 - val_loss: 0.3019 - val_accuracy: 0.8400
# Epoch 27/30
# 7/7 [==============================] - 5s 759ms/step - loss: 0.1082 - accuracy: 0.9918 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 28/30
# 7/7 [==============================] - 5s 746ms/step - loss: 0.1448 - accuracy: 0.9664 - val_loss: 0.2771 - val_accuracy: 0.9200
# Epoch 29/30
# 7/7 [==============================] - 5s 749ms/step - loss: 0.1258 - accuracy: 0.9879 - val_loss: 0.3999 - val_accuracy: 0.8600
# Epoch 30/30
# 7/7 [==============================] - 5s 744ms/step - loss: 0.1019 - accuracy: 0.9980 - val_loss: 0.3049 - val_accuracy: 0.9000
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
from PIL import Image, ImageFilter

im = Image.open('/content/drive/MyDrive/brain tumor/brain_tumor_dataset/no_tumor/36 no.jpg')

# %%
from skimage import transform
def load(filename):
   np_image = filename
   np_image = np.array(np_image).astype('float32')/255
   np_image = transform.resize(np_image, (224, 224, 3))
   np_image = np.expand_dims(np_image, axis=0)
   return np_image

image = load(im)
ans = model.predict(image)

if ans[[0]] < 0.5:
  print('No tumor')
else:
  print('tumor')
# Out:
# No tumor

# %%
model.save('/content/drive/MyDrive/brain tumor/brain_tumor_model')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/brain tumor/brain_tumor_model/assets

# %%
model.save("tumor_model.h5")
